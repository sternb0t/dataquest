# %%
import pandas as pd
avengers = pd.read_csv("./data/avengers.csv", encoding="iso-8859-1")

# %%
avengers.head(5)
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                 NaN                      Sep-63  1963                   52
# 1                 NaN                      Sep-63  1963                   52
# ...

# %%
true_avengers = avengers[avengers["Year"] > 1960].copy()

# %%
true_avengers.shape
# Out:
# (159, 21)

# %%
columns = ['Death1', 'Death2', 'Death3', 'Death4', 'Death5']

# %%
true_avengers[columns].head(20)
# Out:
#    Death1 Death2 Death3 Death4 Death5
# 0     YES    NaN    NaN    NaN    NaN
# 1     YES    NaN    NaN    NaN    NaN
# 2     YES    NaN    NaN    NaN    NaN
# 3     YES    NaN    NaN    NaN    NaN
# 4     YES    YES    NaN    NaN    NaN
# 5      NO    NaN    NaN    NaN    NaN
# 6     YES    NaN    NaN    NaN    NaN
# 7     YES    YES    NaN    NaN    NaN
# 8     YES    NaN    NaN    NaN    NaN
# 9     YES    NaN    NaN    NaN    NaN
# 10    YES    NaN    NaN    NaN    NaN
# 11     NO    NaN    NaN    NaN    NaN
# 12     NO    NaN    NaN    NaN    NaN
# 13    YES    NaN    NaN    NaN    NaN
# 14     NO    NaN    NaN    NaN    NaN
# 15    YES    NaN    NaN    NaN    NaN
# 16    YES    NaN    NaN    NaN    NaN
# 17     NO    NaN    NaN    NaN    NaN
# 18    YES    YES    NaN    NaN    NaN
# 19    YES    NaN    NaN    NaN    NaN

# %%
def num_deaths(row):
    deaths = 0
    for c in columns:
        if row[c] == "YES":
            deaths +=1
    return deaths

# %%
deaths = true_avengers.apply(num_deaths, axis=1)

# %%
true_avengers["Deaths"] = deaths.copy()

# %%
true_avengers["Deaths"].isnull().value_counts()
# Out:
# False    159
# Name: Deaths, dtype: int64

# %%
columns.append("Deaths")

# %%
columns
# Out:
# ['Death1', 'Death2', 'Death3', 'Death4', 'Death5', 'Deaths']

# %%
true_avengers[columns].head(20)
# Out:
#    Death1 Death2 Death3 Death4 Death5  Deaths
# 0     YES    NaN    NaN    NaN    NaN       1
# 1     YES    NaN    NaN    NaN    NaN       1
# 2     YES    NaN    NaN    NaN    NaN       1
# 3     YES    NaN    NaN    NaN    NaN       1
# 4     YES    YES    NaN    NaN    NaN       2
# 5      NO    NaN    NaN    NaN    NaN       0
# 6     YES    NaN    NaN    NaN    NaN       1
# 7     YES    YES    NaN    NaN    NaN       2
# 8     YES    NaN    NaN    NaN    NaN       1
# 9     YES    NaN    NaN    NaN    NaN       1
# 10    YES    NaN    NaN    NaN    NaN       1
# 11     NO    NaN    NaN    NaN    NaN       0
# 12     NO    NaN    NaN    NaN    NaN       0
# 13    YES    NaN    NaN    NaN    NaN       1
# 14     NO    NaN    NaN    NaN    NaN       0
# 15    YES    NaN    NaN    NaN    NaN       1
# 16    YES    NaN    NaN    NaN    NaN       1
# 17     NO    NaN    NaN    NaN    NaN       0
# 18    YES    YES    NaN    NaN    NaN       2
# ...

# %%
(true_avengers["Years since joining"] == 2015 - true_avengers["Year"]).sum()
# Out:
# 159
